# %% [markdown]
# <a href="https://colab.research.google.com/github/sagaraggarwal31/AirBNb_EDA_project/blob/main/EDA_PROJECT_BY_SAGAR_AGGARWAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Name - AirBnb Booking Analysis
# # Contribution -Individual
# # Name -Sagar Aggarwal

# %% [markdown]
# # **Introducing an Airbnb data analysis project **

# %% [markdown]
# # **What is AirBnb ?**

# %% [markdown]
# **Airbnb is an online platform that connects people who are looking for a place to stay with hosts who have extra space to rent out. The platform allows hosts to list their properties, such as apartments, houses, and rooms, and allows guests to search for and book accommodations that fit their needs and budget. Airbnb provides a platform for communication and payment processing between hosts and guests, and takes a commission on each booking. The company has grown rapidly since its founding in 2008 and now operates in over 220 countries and regions around the world.**

# %% [markdown]
# # **Now we analysis AirBnb given dataset and conclude some insightful information .**
#
# **Lets** **Start**

# %% [markdown]
# 1.Importing Libraries
#
# 2.Loading the dataset
#
# 3.Data Cleaning:
#
# Dropping duplicates.
# Cleaning individual columns.
# Remove the Null values from the dataset
# Some Transformations
#
#
# 4.Data Analysis and Visualization: Using plots to find relations between the features
#
# -What is the average preferred price by customers according to the location , different areas of different rrom ?
#
# -Which is the most enganging and disengaging location ?
#
# -Where the customer pays the highest and lowest rent according to location?
#
# -Who  are the top hosts based on their turnover?
#
# -Where the total number of nights spend per location?

# %% [markdown]
# # **Import Libraries**

# %%
#Firstly we Importing all libraries used in this project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
import seaborn as sns

# %% [markdown]
# # **Loading Dataset from Google Drive**

# %%
# Now ,mount google drive for access the dataset of Airbnb
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# In this step we file path of Airbnb dataset in google drive
file_path = "/content/drive/MyDrive/EDA Project 1/"
df = pd.read_csv(file_path + "Airbnb NYC 2019.csv")

# %%
#Information about our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
#Remove latitude, longitude  from a original dataset
df.drop(df.columns[[6,7]], axis=1, inplace=True)

# %%
#Now we  apply dropna() function to entire dataset and drop all null values the entire dataset
AirBnb_df = df.dropna()

# %% [markdown]
# # **Now we analyses data **

# %%
#Information of our new  dataframe
AirBnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 0 to 48852
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   room_type                       38821 non-null  object
#  7   price                           38821 non-null  int64
#  8   minimum_nights                  38821 non-null  int64
#  9   number_of_reviews               38821 non-null  int64
#  10  last_review                     38821 non-null  object
#  11  reviews_per_month               38821 non-null  float64
# ...

# %%
AirBnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
# 5        Chris           Manhattan   Murray Hill  Entire home/apt    200
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
AirBnb_df.tail()
# Out:
#              id                                        name    host_id  \
# 48782  36425863  Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                    No.2 with queen size bed  257683179
# 48799  36438336                             Seas The Moment  211644523
# 48805  36442252               1B-1B apartment near by Metro  273841667
# 48852  36455809     Cozy Private Room in Bushwick, Brooklyn   74162901
#
#        host_name neighbourhood_group    neighbourhood        room_type  price  \
# 48782      Rusaa           Manhattan  Upper East Side     Private room    129
# 48790       H Ai              Queens         Flushing     Private room     45
# 48799        Ben       Staten Island      Great Kills     Private room    235
# 48805     Blaine               Bronx       Mott Haven  Entire home/apt    100
# 48852  Christine            Brooklyn         Bushwick     Private room     30
#
# ...

# %%
#Numerical Information of columns in dataset
AirBnb_df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  3.882100e+04  3.882100e+04  38821.000000    38821.000000
# mean   1.810081e+07  6.424582e+07    142.332526        5.869220
# std    1.069372e+07  7.589752e+07    196.994756       17.389026
# min    2.539000e+03  2.438000e+03      0.000000        1.000000
# 25%    8.721444e+06  7.029525e+06     69.000000        1.000000
# 50%    1.887286e+07  2.837092e+07    101.000000        2.000000
# 75%    2.756746e+07  1.018905e+08    170.000000        4.000000
# max    3.645581e+07  2.738417e+08  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       38821.000000       38821.000000                    38821.000000
# mean           29.290255           1.373229                        5.166611
# std            48.182900           1.680328                       26.302954
# min             1.000000           0.010000                        1.000000
# ...

# %% [markdown]
# #  Now first question comes in a mind is about price offered by host to his customers.
# # So we can find about  the average price in different location , different areas of different rooms
# .

# %%
AirBnb_df.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
#
#       host_name neighbourhood_group       neighbourhood        room_type  \
# 0          John            Brooklyn          Kensington     Private room
# ...

# %% [markdown]
#  **Average price in different locations and areas :**

# %%
avg_location_wise_price = AirBnb_df.groupby(['neighbourhood_group', 'neighbourhood'],as_index = False)['price'].mean().rename(columns={'neighbourhood_group':'Location','neighbourhood':'Area'})

# %%
#print the average location price
avg_location_wise_price
# Out:
#           Location           Area       price
# 0            Bronx       Allerton   90.594595
# 1            Bronx     Baychester   78.000000
# 2            Bronx        Belmont   79.450000
# 3            Bronx      Bronxdale   51.875000
# 4            Bronx    Castle Hill   74.000000
# ..             ...            ...         ...
# 213  Staten Island  Tompkinsville   77.250000
# 214  Staten Island    Tottenville  160.800000
# 215  Staten Island  West Brighton   66.250000
# 216  Staten Island    Westerleigh   71.500000
# 217  Staten Island    Willowbrook  249.000000
#
# [218 rows x 3 columns]

# %% [markdown]
# **Average price in different locations according to the rooms :**

# %%
average_roomwise_price = AirBnb_df.groupby(['neighbourhood_group','room_type'],as_index = False)['price'].mean().rename(columns={'neighbourhood_group':'Location'})
#Print average_roomwise_price
average_roomwise_price
# Out:
#          Location        room_type       price
# 0           Bronx  Entire home/apt  120.938312
# 1           Bronx     Private room   57.093511
# 2           Bronx      Shared room   56.930233
# 3        Brooklyn  Entire home/apt  171.281897
# 4        Brooklyn     Private room   73.349562
# 5        Brooklyn      Shared room   45.458621
# 6       Manhattan  Entire home/apt  230.200964
# 7       Manhattan     Private room  106.607488
# 8       Manhattan      Shared room   77.980337
# 9          Queens  Entire home/apt  139.225603
# 10         Queens     Private room   69.302838
# 11         Queens      Shared room   64.467105
# 12  Staten Island  Entire home/apt  125.366667
# 13  Staten Island     Private room   57.584906
# 14  Staten Island      Shared room   57.600000

# %%
average_room_wise_price = AirBnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
average_room_wise_price
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     120.938312     57.093511    56.930233
# Brooklyn                  171.281897     73.349562    45.458621
# Manhattan                 230.200964    106.607488    77.980337
# Queens                    139.225603     69.302838    64.467105
# Staten Island             125.366667     57.584906    57.600000

# %%
#Graphical representation of average room wise  price of property according to location
average_room_wise_price.plot.bar(color=['mistyrose', 'beige', 'olive'])
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# # **Now we should  find most  engaging and disengaging location for hosts?**

# %%
most_engaged_location = AirBnb_df.groupby('neighbourhood_group',as_index = False)['host_id'].count().sort_values('host_id',ascending= False)
#Print most_engaged_location
most_engaged_location
# Out:
#   neighbourhood_group  host_id
# 2           Manhattan    16621
# 1            Brooklyn    16439
# 3              Queens     4572
# 0               Bronx      875
# 4       Staten Island      314

# %%
# Create a DataFrame
df = pd.DataFrame({
    'neighbourhood_group': ['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'],
    'count': [16621, 16439, 4572, 875, 314]
})

# Create a pie chart showing the distribution of listings in each neighborhood group
plt.figure(figsize=(8, 8))  # Optional: Set the figure size
plt.pie(df['count'], labels=df['neighbourhood_group'], autopct='%1.1f%%', startangle=140)

# Set the title
plt.title('Distribution of Airbnb listings by neighborhood group')

# Display the pie chart
plt.show()

# %% [markdown]
# # We can Conclude that through the above bar graph
# **Manhattan is the most engaging and Staten Island is disengaging  location for Hosts..**

# %% [markdown]
# ## **Where the customer pays the highest and lowest rent according to location?**

# %%
#Get the highest rent according to location
max_price_df = AirBnb_df.groupby('neighbourhood_group',as_index=False)['price'].max().sort_values(['price'],ascending = False).rename(columns = {'price':'Maximum price','neighbourhood_group':'Location'})
max_price_df
# Out:
#         Location  Maximum price
# 1       Brooklyn          10000
# 3         Queens          10000
# 2      Manhattan           9999
# 0          Bronx            800
# 4  Staten Island            625

# %%
#Get the lowest rent according to location
min_price_df = AirBnb_df.groupby('neighbourhood_group',as_index=False)['price'].min().sort_values(['price'],ascending = True).rename(columns = {'price':'Minimum price','neighbourhood_group':'Location'})
min_price_df
# Out:
#         Location  Minimum price
# 0          Bronx              0
# 1       Brooklyn              0
# 2      Manhattan             10
# 3         Queens             10
# 4  Staten Island             13

# %%
#Get the combine dataframe of minimum and maximum price according to location
merge_price_df = pd.merge(max_price_df, min_price_df, on='Location')
merge_price_df
# Out:
#         Location  Maximum price  Minimum price
# 0       Brooklyn          10000              0
# 1         Queens          10000             10
# 2      Manhattan           9999             10
# 3          Bronx            800              0
# 4  Staten Island            625             13

# %%
#Create a copy of merge price dataframe
merge_price_df_copy = merge_price_df.copy()

# %%
#Create a function for log transformation of maximum price and minimum price
def log_values(values):
  '''This function takes a price value as a input and give it's log values'''
  new_max_price = np.log2(values)

  return new_max_price

# %%
#Apply above function on merge price dataframe
merge_price_df_copy['Maximum price'] = merge_price_df_copy.apply(lambda x: log_values(x['Maximum price']), axis=1)
merge_price_df_copy['Minimum price'] = merge_price_df_copy.apply(lambda x: log_values(x['Minimum price']), axis=1)
# Out:
# <ipython-input-25-ecbb41002487>:4: RuntimeWarning: divide by zero encountered in log2
#   new_max_price = np.log2(values)

# %%
#Output of maximum price and minimum price after log transformation
merge_price_df_copy
# Out:
#         Location  Maximum price  Minimum price
# 0       Brooklyn      13.287712           -inf
# 1         Queens      13.287712       3.321928
# 2      Manhattan      13.287568       3.321928
# 3          Bronx       9.643856           -inf
# 4  Staten Island       9.287712       3.700440

# %%
#Bar graph for display maximum price and minimum price according to location
merge_price_df_copy.plot(x="Location", y=['Maximum price','Minimum price'], kind="bar")
plt.legend(labels = ['Maximum price','Minimum price'])
plt.title('Maximum and minimum price according to location')
# Out:
# Text(0.5, 1.0, 'Maximum and minimum price according to location')

# %% [markdown]
# #Find the top three hosts based on their turnover

# %%
# Datavisualization of null value
AirBnb_df.isnull()
sns.heatmap(AirBnb_df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
# After removing last_review , reviews_per_month columns
AirBnb_df.drop(['last_review', 'reviews_per_month'], axis = 1,inplace=True)

# %%
#Find any dupicated value
AirBnb_df.duplicated().sum()
# Out:
# 0

# %%
# Returns  booleans if a column value contains nulls
AirBnb_df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# 5      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48782  False  False    False      False                False          False
# 48790  False  False    False      False                False          False
# 48799  False  False    False      False                False          False
# 48805  False  False    False      False                False          False
# 48852  False  False    False      False                False          False
#
# ...

# %%
# Datavisualization of null value after removing last_review , reviews_per_month columns
sns.heatmap(AirBnb_df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
# Drop null value from the dataset
non_null_file = AirBnb_df.dropna()
non_null_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 0 to 48852
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   room_type                       38821 non-null  object
#  7   price                           38821 non-null  int64
#  8   minimum_nights                  38821 non-null  int64
#  9   number_of_reviews               38821 non-null  int64
#  10  calculated_host_listings_count  38821 non-null  int64
#  11  availability_365                38821 non-null  int64
# ...

# %%
# Copy of the non_null_file
New_df=non_null_file.copy()
New_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
# 5        Chris           Manhattan   Murray Hill  Entire home/apt    200
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
New_df['price'].describe()
# Out:
# count    38821.000000
# mean       142.332526
# std        196.994756
# min          0.000000
# 25%         69.000000
# 50%        101.000000
# 75%        170.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# Replace whose price less than 50
New_df.loc[New_df['price']<50,'price'] = New_df.loc[(New_df['price']>50) & (New_df['price']<80),'price'].median()
New_df['price'].describe()
# Out:
# count    38821.000000
# mean       144.934262
# std        195.771964
# min         50.000000
# 25%         69.000000
# 50%        101.000000
# 75%        170.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# After removing price less than 100

New_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
# 5        Chris           Manhattan   Murray Hill  Entire home/apt    200
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
#  Find the maximum price across different host name
top_host=New_df.groupby(['host_name','host_id'])['price'].sum().reset_index()
top_host.rename(columns={'price':'total_price'},inplace=True)
top_host.head()

#Top_host.info()
# Out:
#                   host_name   host_id  total_price
# 0                      'Cil  45354224          120
# 1           (Ari) HENRY LEE  40605120          140
# 2  (Email hidden by Airbnb)   5610823          261
# 3  (Email hidden by Airbnb)   7580102          389
# 4  (Email hidden by Airbnb)  11495251          200

# %%
# Find top three host best on their turnover
top_3=top_host.sort_values('total_price',ascending=False).iloc[:3,:3]
top_3
# Out:
#           host_name    host_id  total_price
# 26844  Sonder (NYC)  219517861        55920
# 24115    Red Awning  205031545        24194
# 11329         Henry     836168        19500

# %%
sns.set(rc={'figure.figsize':(8,10)})
sns.set_style('white')
abc= sns.barplot(x='host_name',y='total_price',data = top_3)
abc.set_title('three hosts based on their turnover', weight='bold')
abc.set_ylabel('host name', weight='bold')
abc.set_xlabel('total price', weight='bold')

abc.set_xticklabels(abc.get_xticklabels(),weight='bold',rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Sonder (NYC)'), Text(1, 0, 'Red Awning'), Text(2, 0, 'Henry')]

# %% [markdown]
# #Find total no. nights spend per location?

# %%
total_nights=New_df.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index()
final_nights=total_nights.sort_values('minimum_nights',ascending=True)
final_nights.head()
# Out:
#   neighbourhood_group  minimum_nights
# 4       Staten Island            1074
# 0               Bronx            3441
# 3              Queens           19305
# 1            Brooklyn           87458
# 2           Manhattan          116571

# %%
# visualization of total no. nights spend per location using seaborn
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
abc= sns.barplot(x='neighbourhood_group',y='minimum_nights',data = final_nights)
abc.set_title('find total no. nights spend per location', weight='bold')
abc.set_ylabel('minimum night', weight='bold')
abc.set_xlabel('neighbourhood group', weight='bold')

abc.set_xticklabels(abc.get_xticklabels(),weight='bold',rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Staten Island'),
#  Text(1, 0, 'Bronx'),
#  Text(2, 0, 'Queens'),
#  Text(3, 0, 'Brooklyn'),
#  Text(4, 0, 'Manhattan')]

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# - Customers pay highest amount in Brooklyn,Queens and Manhattan that is 10,000 and lowest amount is 10$.
#
# - Manhattan is the most engaging and Staten Island is disengaging  location for Hosts
#
# - For the three types of room type (i.e. Entire home, Shared room, & Private room) average price of entire home is around $157, for shared room is around 60, and for private room is around 75.
#
# - Based on turnover Hosts(Sonder (NYC),Blueground,Sally) has total price  (82795 , 70331,37097)
#
# - People stay more nights in Brooklyn and Manhattan. So it is also the busiest place .
